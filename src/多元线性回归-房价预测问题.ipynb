# %%
import sys

print(sys.path)
# Out:
# ['D:\\PyCharm\\scikit-learn-training\\src', 'D:\\Python\\Anaconda\\python37.zip', 'D:\\Python\\Anaconda\\DLLs', 'D:\\Python\\Anaconda\\lib', 'D:\\Python\\Anaconda', '', 'D:\\Python\\Anaconda\\lib\\site-packages', 'D:\\Python\\Anaconda\\lib\\site-packages\\win32', 'D:\\Python\\Anaconda\\lib\\site-packages\\win32\\lib', 'D:\\Python\\Anaconda\\lib\\site-packages\\Pythonwin', 'D:\\Python\\Anaconda\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\yk\\.ipython']

# %%
import numpy as np
import matplotlib.pyplot as plt

x, y = [], []

for sample in open("../data/prices.txt", "r"):
    _x, _y = sample.split(",")
    x.append(float(_x))
    y.append(float(_y))

x, y = np.array(x), np.array(y)
# 标准化
x = (x - x.mean()) / x.std()

plt.figure()
plt.scatter(x, y, c="g", s=6)
plt.show()

# %%
x0 = np.linspace(-2, 4, 100)


def get_model(deg):
    return lambda input_x=x0: np.polyval(np.polyfit(x, y, deg), input_x)


def get_cost(deg, input_x, input_y):
    return 0.5 * ((get_model(deg)(input_x) - input_y) ** 2).sum()


test_set = (1, 4, 10)

for d in test_set:
    print(get_cost(d, x, y))
# Out:
# 96732238800.35297
# 94112406641.67743
# 75874846680.09282

# %%
plt.scatter(x, y, c="g", s=20)

for d in test_set:
    plt.plot(x0, get_model(d)(), label="degree = {}".format(d))

plt.xlim(-2, 4)
plt.ylim(1e5, 9e5)
plt.legend()
plt.show()
